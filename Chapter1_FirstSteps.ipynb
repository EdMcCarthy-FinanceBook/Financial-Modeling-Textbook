# %% [markdown]
# <a href="https://colab.research.google.com/github/EdMcCarthy-FinanceBook/Financial-Modeling-Textbook/blob/main/Chapter1_FirstSteps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = 50
quantity = 10
total = price * quantity

print("The total value is:", total)
# Out:
# The total value is: 500

# %% [markdown]
# # Module 1: First Contact with the Cloud
#
# **Objective:** Specific goals for this session include running your first Python command, understanding the difference between Code and Text, and mastering the "Run" button.
#
# ### How to use this notebook
# 1. **Read** the text explanations.
# 2. **Run** the code blocks by clicking the "Play" button (▶) on the left side of the cell.
# 3. **Edit** sections when prompted to see how the computer responds.

# %% [markdown]
# ## Part 1: The Code Cell
# Below is a "Code Cell." It is a direct line to the Python engine.
#
# **Action:** Click the Play button on the cell below.
